# %% [markdown]
# This Notebook will be used for the Capstone Project

# %% [markdown]
# INTRODUCTION:
# For this project we'll be using the example dataset given by the course to predict the accident severity of seattle. This city is a place where rainfall is experienced for an average of eighteen days per month and also having high levels of humidity it makes it a perfect place to study car accident severity due to the weather.
# Seattle had set a goal that for 2030 they'll have 0% of fatal or serious injuries for car accidents. Although this numbers have decreased through the years it seems very unlikely that the city will reach this goal for 2030. So the purpose of this project y to predict the severity of this accidents due to several variables so that the city can take action.

# %% [markdown]
# Data Description:
# I'll be using the example data set given by the course that contains 194673 rows and 38 columns of data. This columns contains a vast amount of variables such as location, vehicle count, road condition and lightning condition, weather, collision type and many others.
# With this information i'll train the dataset to predict the accident severity due to most of this variables but most of it focused on the weather and road conditions. I'll need to separate this data set to a train dataset and a test dataset to have the best results possible.

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %%
dataset = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv')
dataset.shape
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (194673, 38)

# %%
dataset.dtypes.count
# Out:
# <bound method Series.count of SEVERITYCODE        int64
# X                 float64
# Y                 float64
# OBJECTID            int64
# STATUS             object
# ADDRTYPE           object
# LOCATION           object
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# HITPARKEDCAR       object
# dtype: object>

# %%
dataset.rename(columns = {'OBJECTID':'Object_ID','STATUS':'Status','ADDRTYPE':'Adress_type','LOCATION':'Location', 'SEVERITYDESC': 'Severity_description', 'COLLISIONTYPE':'Collision_type', 'PERSONCOUNT':'Person_count', 'VEHCOUNT':'Vehicle_count', 'INCDATE':'Incident_date', 'JUNCTIONTYPE': 'Intercep_type', 'SDOT_COLCODE':'Crash_type_code', 'SDOT_COLDESC':'Crash_type', 'UNDERINFL':'Tire_inflated','WEATHER':'Weather', 'ROADCOND':'Road_condition', 'LIGHTCOND': 'streetlight_condition', 'SPEEDING': 'Speeding', 'ST_COLCODE':'Crash_description_code', 'ST_COLDESC':'Crash_description', 'HITPARKEDCAR':'Parked_car_crash'}, inplace = True)

# %%
dataset
# Out:
#         SEVERITYCODE           X          Y  Object_ID     Status  \
# 0                  2 -122.323148  47.703140          1    Matched
# 1                  1 -122.347294  47.647172          2    Matched
# 2                  1 -122.334540  47.607871          3    Matched
# 3                  1 -122.334803  47.604803          4    Matched
# 4                  2 -122.306426  47.545739          5    Matched
# 5                  1 -122.387598  47.690575          6    Matched
# 6                  1 -122.338485  47.618534          7    Matched
# 7                  2 -122.320780  47.614076          9    Matched
# 8                  1 -122.335930  47.611904         10    Matched
# 9                  2 -122.384700  47.528475         12    Matched
# 10                 1         NaN        NaN         14    Matched
# 11                 1 -122.333831  47.547371         15    Matched
# 12                 1 -122.356273  47.571375         16  Unmatched
# 13                 1 -122.323966  47.606374         17    Matched
# 14                 2 -122.317414  47.664028         19    Matched
# 15                 1 -122.337663  47.617510         20  Unmatched
# 16                 2 -122.344539  47.692012         21    Matched
# 17                 1         NaN        NaN         23    Matched
# 18                 2 -122.328270  47.571420         24    Matched
# 19                 1 -122.383802  47.583715         25    Matched
# 20                 2 -122.292403  47.732847         26    Matched
# 21                 2 -122.313786  47.708535         28    Matched
# 22                 1 -122.318169  47.615837         29    Matched
# 23                 1 -122.337486  47.589746         31    Matched
# 24                 2 -122.279658  47.553405         33    Matched
# 25                 2 -122.312857  47.599218         34    Matched
# 26                 1 -122.330730  47.615450         35    Matched
# 27                 1 -122.385859  47.581191         36    Matched
# 28                 1 -122.304990  47.611474         37    Matched
# 29                 1         NaN        NaN         38    Matched
# ...              ...         ...        ...        ...        ...
# 194643             1 -122.345863  47.612991     219510    Matched
# 194644             1 -122.330298  47.603233     219511    Matched
# 194645             2 -122.328079  47.604161     219512    Matched
# 194646             1 -122.320756  47.608656     219513  Unmatched
# 194647             2 -122.355449  47.704720     219514    Matched
# 194648             1 -122.357624  47.635956     219515    Matched
# 194649             2 -122.302382  47.626759     219516    Matched
# 194650             2 -122.355298  47.684382     219517    Matched
# 194651             1 -122.320780  47.614076     219519    Matched
# 194652             1 -122.335527  47.617434     219520    Matched
# 194653             2 -122.322097  47.649615     219521    Matched
# 194654             1 -122.312679  47.719414     219522  Unmatched
# 194655             2 -122.380016  47.664879     219523  Unmatched
# 194656             2 -122.340474  47.614496     219524    Matched
# 194657             1 -122.337137  47.610709     219525    Matched
# 194658             1 -122.302554  47.584099     219528    Matched
# 194659             1 -122.298955  47.717456     219529    Matched
# 194660             2         NaN        NaN     219531    Matched
# 194661             2 -122.306092  47.617881     219532    Matched
# 194662             1 -122.337880  47.625793     219535    Matched
# 194663             2 -122.299160  47.579673     219536    Matched
# 194664             1 -122.325887  47.643191     219537    Matched
# 194665             1 -122.304217  47.669537     219538    Matched
# 194666             2 -122.344569  47.694547     219539    Matched
# 194667             1 -122.361672  47.556722     219541    Matched
# 194668             2 -122.290826  47.565408     219543    Matched
# 194669             1 -122.344526  47.690924     219544    Matched
# 194670             2 -122.306689  47.683047     219545    Matched
# 194671             2 -122.355317  47.678734     219546    Matched
# 194672             1 -122.289360  47.611017     219547    Matched
#
#          Adress_type                                           Location  \
# 0       Intersection                         5TH AVE NE AND NE 103RD ST
# 1              Block         AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N
# 2              Block        4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST
# 3              Block           2ND AVE BETWEEN MARION ST AND MADISON ST
# 4       Intersection                    SWIFT AVE S AND SWIFT AV OFF RP
# 5       Intersection                         24TH AVE NW AND NW 85TH ST
# 6       Intersection                         DENNY WAY AND WESTLAKE AVE
# 7       Intersection                             BROADWAY AND E PIKE ST
# 8              Block                PINE ST BETWEEN 5TH AVE AND 6TH AVE
# 9       Intersection                      41ST AVE SW AND SW THISTLE ST
# 10             Alley                                                NaN
# 11      Intersection             1ST AV S BR NB AND EAST MARGINAL WAY S
# 12             Block  SW SPOKANE ST BETWEEN SW SPOKANE W BR AND TERM...
# 13             Block           TERRY AVE BETWEEN JAMES ST AND CHERRY ST
# 14             Block  ROOSEVELT WAY NE BETWEEN NE 47TH ST AND NE 50T...
# 15             Block         9TH AVE BETWEEN LENORA ST AND BLANCHARD ST
# 16      Intersection                         AURORA AVE N AND N 87TH ST
# 17             Block  BATTERY ST TUN ON RP BETWEEN BELL ST AND ALASK...
# 18             Block    S SPOKANE SR ST BETWEEN 4TH AVE S AND 5TH AVE S
# 19             Block  41ST AVE SW BETWEEN SW WALKER ST AND SW COLLEG...
# 20             Block  LAKE CITY WAY NE BETWEEN NE 143RD ST AND NE 14...
# 21      Intersection                   14TH AVE NE AND NE NORTHGATE WAY
# 22             Block          11TH AVE BETWEEN E PINE ST AND E OLIVE ST
# 23             Block  ALASKAN WY VI SB BETWEEN ALASKAN WY VI SB EFR ...
# 24      Intersection                     RAINIER AVE S AND S BRANDON ST
# 25             Block     S JACKSON ST BETWEEN 14TH AVE S AND 16TH AVE S
# 26      Intersection                            BOREN AVE AND OLIVE WAY
# 27             Block  SW ADMIRAL WAY BETWEEN 42ND AVE SW AND CALIFOR...
# 28             Block        21ST AVE BETWEEN E MARION ST AND E UNION ST
# 29             Block  1ST AVE S BETWEEN 1ST AVS ON N RP AND S ROYAL ...
# ...              ...                                                ...
# 194643         Block           1ST AVE BETWEEN BLANCHARD ST AND BELL ST
# 194644  Intersection                               4TH AVE AND JAMES ST
# 194645  Intersection                               6TH AVE AND JAMES ST
# 194646         Block       BROADWAY BETWEEN CHERRY ST AND E COLUMBIA ST
# 194647         Block  GREENWOOD AVE N BETWEEN N 104TH ST AND HOLMAN ...
# 194648         Block   W HOWE ST BETWEEN QUEEN ANNE AVE N AND 1ST AVE W
# 194649  Intersection                          23RD AVE E AND E ALOHA ST
# 194650         Block    GREENWOOD AVE N BETWEEN N 76TH ST AND N 77TH ST
# 194651  Intersection                             BROADWAY AND E PIKE ST
# 194652         Block        TERRY AVE BETWEEN VIRGINIA ST AND LENORA ST
# 194653         Block  HARVARD AVE E BETWEEN E ALLISON ST AND EASTLAK...
# 194654  Intersection                        15TH AVE NE AND NE 125TH ST
# 194655  Intersection                        LEARY AVE NW AND NW DOCK PL
# 194656  Intersection                              5TH AVE AND LENORA ST
# 194657         Block                4TH AVE BETWEEN PIKE ST AND PINE ST
# 194658         Block   RAINIER AVE S BETWEEN 23RD AVE S AND S WALKER ST
# 194659         Block    NE 123RD ST BETWEEN HIRAM PL NE AND 28TH AVE NE
# 194660         Block  BATTERY ST TUNNEL NB BETWEEN ALASKAN WY VI NB ...
# 194661         Block      20TH AVE BETWEEN E MADISON ST AND E DENNY WAY
# 194662         Block   VALLEY ST BETWEEN WESTLAKE AVE N AND TERRY AVE N
# 194663         Block  RAINIER AVE S BETWEEN S BAYVIEW ST AND S MCCLE...
# 194664  Intersection                    EASTLAKE AVE E AND E ROANOKE ST
# 194665  Intersection                    NE PARK RD AND NE RAVENNA WB BV
# 194666         Block       AURORA AVE N BETWEEN N 90TH ST AND N 91ST ST
# 194667         Block  PUGET BLVD SW BETWEEN SW HUDSON ST AND DEAD END 1
# 194668         Block    34TH AVE S BETWEEN S DAKOTA ST AND S GENESEE ST
# 194669         Block       AURORA AVE N BETWEEN N 85TH ST AND N 86TH ST
# 194670  Intersection                         20TH AVE NE AND NE 75TH ST
# 194671  Intersection                      GREENWOOD AVE N AND N 68TH ST
# 194672         Block       34TH AVE BETWEEN E MARION ST AND E SPRING ST
#
#                   Severity_description Collision_type  Person_count  ...  \
# 0                     Injury Collision         Angles             2  ...
# 1       Property Damage Only Collision      Sideswipe             2  ...
# 2       Property Damage Only Collision     Parked Car             4  ...
# 3       Property Damage Only Collision          Other             3  ...
# 4                     Injury Collision         Angles             2  ...
# 5       Property Damage Only Collision         Angles             2  ...
# 6       Property Damage Only Collision         Angles             2  ...
# 7                     Injury Collision         Cycles             3  ...
# 8       Property Damage Only Collision     Parked Car             2  ...
# 9                     Injury Collision         Angles             2  ...
# 10      Property Damage Only Collision          Other             2  ...
# 11      Property Damage Only Collision         Angles             2  ...
# 12      Property Damage Only Collision     Rear Ended             0  ...
# 13      Property Damage Only Collision     Parked Car             2  ...
# 14                    Injury Collision        Head On             2  ...
# 15      Property Damage Only Collision            NaN             1  ...
# 16                    Injury Collision      Left Turn             3  ...
# 17      Property Damage Only Collision     Rear Ended             0  ...
# 18                    Injury Collision     Rear Ended             4  ...
# 19      Property Damage Only Collision     Parked Car             2  ...
# 20                    Injury Collision     Rear Ended             3  ...
# 21                    Injury Collision         Angles             5  ...
# 22      Property Damage Only Collision     Parked Car             2  ...
# 23      Property Damage Only Collision          Other             1  ...
# 24                    Injury Collision     Rear Ended             3  ...
# 25                    Injury Collision         Cycles             2  ...
# 26      Property Damage Only Collision      Left Turn             2  ...
# 27      Property Damage Only Collision         Angles             2  ...
# 28      Property Damage Only Collision          Other             2  ...
# 29      Property Damage Only Collision     Parked Car             2  ...
# ...                                ...            ...           ...  ...
# 194643  Property Damage Only Collision     Parked Car             2  ...
# 194644  Property Damage Only Collision         Angles             2  ...
# 194645                Injury Collision     Right Turn             5  ...
# 194646  Property Damage Only Collision            NaN             2  ...
# 194647                Injury Collision     Pedestrian             2  ...
# 194648  Property Damage Only Collision         Angles             2  ...
# 194649                Injury Collision      Left Turn             6  ...
# 194650                Injury Collision     Parked Car             5  ...
# 194651  Property Damage Only Collision     Pedestrian             3  ...
# 194652  Property Damage Only Collision     Parked Car             3  ...
# 194653                Injury Collision     Parked Car             6  ...
# 194654  Property Damage Only Collision            NaN             2  ...
# 194655                Injury Collision            NaN             4  ...
# 194656                Injury Collision     Pedestrian             2  ...
# 194657  Property Damage Only Collision      Sideswipe             2  ...
# 194658  Property Damage Only Collision     Rear Ended             3  ...
# 194659  Property Damage Only Collision     Parked Car             2  ...
# 194660                Injury Collision          Other             1  ...
# 194661                Injury Collision      Left Turn             2  ...
# 194662  Property Damage Only Collision     Parked Car             2  ...
# 194663                Injury Collision         Angles             3  ...
# 194664  Property Damage Only Collision         Angles             8  ...
# 194665  Property Damage Only Collision         Angles             2  ...
# 194666                Injury Collision         Angles             2  ...
# 194667  Property Damage Only Collision          Other             1  ...
# 194668                Injury Collision        Head On             3  ...
# 194669  Property Damage Only Collision     Rear Ended             2  ...
# 194670                Injury Collision      Left Turn             3  ...
# 194671                Injury Collision         Cycles             2  ...
# 194672  Property Damage Only Collision     Rear Ended             2  ...
#
#                                                Crash_type INATTENTIONIND  \
# 0       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 1       MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN
# 2            MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 3       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 4       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 5       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 6       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 7       PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...            NaN
# 8       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 9       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 10      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 11      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 12           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 13      MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN
# 14      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 15                    MOTOR VEHICLE STRUCK OBJECT IN ROAD            NaN
# 16      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 17           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 18           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 19      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 20           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 21      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 22      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...              Y
# 23          MOTOR VEHICLE RAN OFF ROAD - HIT FIXED OBJECT            NaN
# 24           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 25      MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...              Y
# 26      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 27      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 28           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 29      MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN
# ...                                                   ...            ...
# 194643  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194644  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194645  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194646       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194647       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END              Y
# 194648  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194649  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194650       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194651                    MOTOR VEHCILE STRUCK PEDESTRIAN            NaN
# 194652  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...              Y
# 194653  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194654  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194655                    MOTOR VEHCILE STRUCK PEDESTRIAN            NaN
# 194656                    MOTOR VEHCILE STRUCK PEDESTRIAN            NaN
# 194657            NOT ENOUGH INFORMATION / NOT APPLICABLE            NaN
# 194658       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194659            NOT ENOUGH INFORMATION / NOT APPLICABLE            NaN
# 194660                   MOTOR VEHICLE OVERTURNED IN ROAD            NaN
# 194661       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194662       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194663  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...              Y
# 194664  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194665  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194666  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194667      MOTOR VEHICLE RAN OFF ROAD - HIT FIXED OBJECT            NaN
# 194668  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194669       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END              Y
# 194670  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194671  PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...            NaN
# 194672       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
#
#        Tire_inflated   Weather Road_condition    streetlight_condition  \
# 0                  N  Overcast            Wet                 Daylight
# 1                  0   Raining            Wet  Dark - Street Lights On
# 2                  0  Overcast            Dry                 Daylight
# 3                  N     Clear            Dry                 Daylight
# 4                  0   Raining            Wet                 Daylight
# 5                  N     Clear            Dry                 Daylight
# 6                  0   Raining            Wet                 Daylight
# 7                  N     Clear            Dry                 Daylight
# 8                  0     Clear            Dry                 Daylight
# 9                  0     Clear            Dry                 Daylight
# 10                 0  Overcast            Dry                 Daylight
# 11                 0     Clear            Dry                 Daylight
# 12                 0   Raining            Wet  Dark - Street Lights On
# 13                 0   Raining            Wet  Dark - No Street Lights
# 14                 N     Clear            Dry  Dark - Street Lights On
# 15               NaN       NaN            NaN                      NaN
# 16                 0  Overcast            Dry                 Daylight
# 17                 0  Overcast            Dry                 Daylight
# 18                 N     Clear            Dry                 Daylight
# 19                 0   Unknown            Dry                  Unknown
# 20                 N     Clear            Dry  Dark - Street Lights On
# 21                 N     Clear            Dry                 Daylight
# 22                 0     Clear            Dry  Dark - Street Lights On
# 23                 0   Unknown        Unknown                  Unknown
# 24                 N     Clear            Dry                 Daylight
# 25                 N     Clear            Dry                 Daylight
# 26                 N  Overcast            Wet                  Unknown
# 27                 0     Clear            Dry                 Daylight
# 28                 N     Clear            Dry                 Daylight
# 29                 0     Clear            Dry                 Daylight
# ...              ...       ...            ...                      ...
# 194643             N     Clear            Dry  Dark - Street Lights On
# 194644             N     Clear            Dry                     Dusk
# 194645             N     Clear            Dry  Dark - Street Lights On
# 194646           NaN       NaN            NaN                      NaN
# 194647             N   Raining            Wet                     Dusk
# 194648             Y   Raining            Wet  Dark - Street Lights On
# 194649             N     Clear            Dry  Dark - Street Lights On
# 194650             N     Clear            Dry                 Daylight
# 194651             N     Clear            Wet  Dark - Street Lights On
# 194652             N  Overcast            Wet                     Dusk
# 194653             Y  Overcast            Wet  Dark - Street Lights On
# 194654           NaN       NaN            NaN                      NaN
# 194655           NaN       NaN            NaN                      NaN
# 194656             N     Clear            Dry                 Daylight
# 194657             N   Raining            Wet  Dark - Street Lights On
# 194658             N   Raining            Wet  Dark - Street Lights On
# 194659             N   Raining            Wet  Dark - Street Lights On
# 194660             N   Raining            Wet                    Other
# 194661             Y     Clear            Dry                 Daylight
# 194662             N     Clear            Dry                     Dusk
# 194663             N   Raining            Wet                 Daylight
# 194664             N     Clear            Dry                 Daylight
# 194665             N     Clear            Dry                 Daylight
# 194666             N     Clear            Wet                 Daylight
# 194667             Y   Raining            Wet  Dark - Street Lights On
# 194668             N     Clear            Dry                 Daylight
# 194669             N   Raining            Wet                 Daylight
# 194670             N     Clear            Dry                 Daylight
# 194671             N     Clear            Dry                     Dusk
# 194672             N     Clear            Wet                 Daylight
#
#        Speeding Crash_description_code  \
# 0           NaN                     10
# 1           NaN                     11
# 2           NaN                     32
# 3           NaN                     23
# 4           NaN                     10
# 5           NaN                     10
# 6           NaN                     10
# 7           NaN                      5
# 8           NaN                     32
# 9           NaN                     10
# 10          NaN                     22
# 11          NaN                     10
# 12          NaN                     14
# 13          NaN                     32
# 14          NaN                     30
# 15          NaN
# 16          NaN                     28
# 17          NaN                     14
# 18          NaN                     14
# 19          NaN                     32
# 20          NaN                     14
# 21          NaN                     10
# 22          NaN                     32
# 23          NaN                     51
# 24            Y                     14
# 25          NaN                      5
# 26          NaN                     28
# 27          NaN                     10
# 28          NaN                     23
# 29          NaN                     32
# ...         ...                    ...
# 194643      NaN                     20
# 194644      NaN                     10
# 194645      NaN                     16
# 194646      NaN
# 194647      NaN                      0
# 194648      NaN                     10
# 194649      NaN                     28
# 194650      NaN                     32
# 194651      NaN                      0
# 194652      NaN                     32
# 194653      NaN                     32
# 194654      NaN
# 194655      NaN
# 194656      NaN                      2
# 194657      NaN                     11
# 194658      NaN                     14
# 194659      NaN                     32
# 194660      NaN                     52
# 194661      NaN                     29
# 194662      NaN                     32
# 194663      NaN                     10
# 194664      NaN                     10
# 194665      NaN                     10
# 194666      NaN                     10
# 194667      NaN                     50
# 194668      NaN                     24
# 194669      NaN                     13
# 194670      NaN                     28
# 194671      NaN                      5
# 194672      NaN                     14
#
#                                         Crash_description Parked_car_crash
# 0                                       Entering at angle                N
# 1       From same direction - both going straight - bo...                N
# 2                                  One parked--one moving                N
# 3                        From same direction - all others                N
# 4                                       Entering at angle                N
# 5                                       Entering at angle                N
# 6                                       Entering at angle                N
# 7                            Vehicle Strikes Pedalcyclist                N
# 8                                  One parked--one moving                N
# 9                                       Entering at angle                N
# 10                        One car leaving driveway access                N
# 11                                      Entering at angle                N
# 12      From same direction - both going straight - on...                N
# 13                                 One parked--one moving                N
# 14                   From opposite direction - all others                N
# 15                                                    NaN                N
# 16      From opposite direction - one left turn - one ...                N
# 17      From same direction - both going straight - on...                N
# 18      From same direction - both going straight - on...                N
# 19                                 One parked--one moving                N
# 20      From same direction - both going straight - on...                N
# 21                                      Entering at angle                N
# 22                                 One parked--one moving                N
# 23                                           Other object                N
# 24      From same direction - both going straight - on...                N
# 25                           Vehicle Strikes Pedalcyclist                N
# 26      From opposite direction - one left turn - one ...                N
# 27                                      Entering at angle                N
# 28                       From same direction - all others                N
# 29                                 One parked--one moving                N
# ...                                                   ...              ...
# 194643                    One car leaving parked position                N
# 194644                                  Entering at angle                N
# 194645  From same direction - one right turn - one str...                N
# 194646                                                NaN                N
# 194647             Vehicle going straight hits pedestrian                N
# 194648                                  Entering at angle                N
# 194649  From opposite direction - one left turn - one ...                N
# 194650                             One parked--one moving                Y
# 194651             Vehicle going straight hits pedestrian                N
# 194652                             One parked--one moving                Y
# 194653                             One parked--one moving                Y
# 194654                                                NaN                N
# 194655                                                NaN                N
# 194656               Vehicle turning left hits pedestrian                N
# 194657  From same direction - both going straight - bo...                N
# 194658  From same direction - both going straight - on...                N
# 194659                             One parked--one moving                Y
# 194660                                 Vehicle overturned                N
# 194661  From opposite direction - one left turn - one ...                N
# 194662                             One parked--one moving                Y
# 194663                                  Entering at angle                N
# 194664                                  Entering at angle                N
# 194665                                  Entering at angle                N
# 194666                                  Entering at angle                N
# 194667                                       Fixed object                N
# 194668    From opposite direction - both moving - head-on                N
# 194669  From same direction - both going straight - bo...                N
# 194670  From opposite direction - one left turn - one ...                N
# 194671                       Vehicle Strikes Pedalcyclist                N
# 194672  From same direction - both going straight - on...                N
#
# [194673 rows x 24 columns]
